# %% [markdown]
# **MATERIA:** MACHINE LEARNING
#
# **PROYECTO:** "CAR SALES"
#
# **DOCENTE:** Msc. Lic. ERIKA PATRICIA RODRIGUEZ BILBAO
#
# **INTEGRANTES DEL GRUPO:**
#
# Aguilar Villalobos Fernanda
#
# Fernández Sánchez Reilly Daria
#
# Guzmán Galarza Violeta Belén
#
# Maguiña Apaza Pablo Saul
#
# Menacho Flores Dennys Lee

# %% [markdown]
# # I. INTRODUCCION

# %% [markdown]
# En el siguiente trabajo se presentará el proceso de aplicar el aprendizaje automático a través de modelos regresionales y de decisión para predecir:
#
# a) El precio de un automovil, mediante un modelo regresional según parámetros determinados. En el mercado de la venta de autos puede haber una gran variabilidad de precios de acuerdo a varios factores como la marca, el modelo, el estado, si es nuevo o usado, etc. Por lo cual por medio de la predicción de precios se obtendrá un precio estimado para tomar  en cuenta al momento de realizar una compra y comparar con los precios ofrecidos.
#
# b) El año del modelo de un automovil, mediante un modelo de decisión segun parametros determinados.

# %% [markdown]
# # II. OBJETIVOS

# %% [markdown]
# Realizar la evaluación e implementación de  procesos de Aprendizaje Automático , a través del análisis del dataset de venta de autos para predecir tanto el precio de un auto con un modelo regresional, como el año del modelo de un auto con un modelo de decisión.

# %% [markdown]
# # III. MARCO TEORICO

# %% [markdown]
# > **a) Venta de automoviles**
# El mercado de la venta de automóviles suele crecer con el paso del tiempo debido a la necesidad de las personas en comprar un automóvil por diversos factores como la capacidad de poder movilizarse de un lugar a otro, la sensación de libertad, uso como herramienta de trabajo, etc.
#
# > **b) Machine Learning**
# El aprendizaje automático es una aplicación de IA que permite que los sistemas aprendan y mejoren a partir de la experiencia sin ser programados explícitamente. El aprendizaje automático se centra en el desarrollo de programas informáticos que pueden acceder a los datos y utilizarlos para aprender por sí mismos.
#
# > **c) Aprendizaje Automatico**
# >> **Aprendizaje Supervisado:**
# Los algoritmos de aprendizaje supervisado basan su aprendizaje en un juego de datos de entrenamiento previamente etiquetados. Por etiquetado entendemos que para cada ocurrencia del juego de datos de entrenamiento conocemos el valor de su atributo objetivo. Esto le permitirá al algoritmo poder “aprender” una función capaz de predecir el atributo objetivo para un juego de datos nuevo.
#
# >> **Aprendizaje No Supervisado:**
# Los métodos no supervisados (unsupervised methods) son algoritmos que basan su proceso de entrenamiento en un juego de datos sin etiquetas o clases previamente deﬁnidas. Es decir, a priori no se conoce ningún valor objetivo o de clase, ya sea categórico o numérico. El aprendizaje no supervisado está dedicado a las tareas de agrupamiento, también llamadas clustering o segmentación, donde su objetivo es encontrar grupos similares en el conjunto de datos.
#
#
# > **d) Regresión Lineal**
# Una regresión lineal se utiliza para generar predicciones sobre una variable que llamamos la variable dependiente, generalmente denominada con una y, dadas una o varias variables independientes generalmente denominadas las x. Cuando usamos regresión lineal, la variable dependiente y siempre es numérica. Por ejemplo, precios de las casas, estaturas, la distancia de los planetas al sol, etc. Una regresión lineal en su forma más simple (cuando contamos con solo una variable independiente x) es una línea recta en dos dimensiones que mejor se ajusta a los valores de los datos.
#
# > **e) Regresión Polinomial**
# La regresión polinomial es un algoritmo de regresión que modela la relación entre una variable dependiente (y) e independiente (x) como un polinomio de grado n. La ecuación de regresión polinomial se da a continuación:
#
#
# > **f) Random Forest**
# Random Forest es un algoritmo de aprendizaje automático que pertenece a la técnica de aprendizaje supervisado. Se puede usar para problemas de clasificación y regresión en ML. Se basa en el concepto de aprendizaje conjunto, que es un proceso de combinación de múltiples clasificadores para resolver un problema complejo y mejorar el rendimiento del modelo.
#
# > **g) Decision Tree Regression**
# Decision Tree es una herramienta de toma de decisiones que utiliza una estructura de árbol similar a un diagrama de flujo o es un modelo de decisiones y todos sus posibles resultados, incluidos los resultados, los costos de entrada y la utilidad.
# El algoritmo del árbol de decisiones cae dentro de la categoría de algoritmos de aprendizaje supervisado. Funciona tanto para variables de salida continuas como categóricas.
#
# > **h) Regresión Logística**
# La regresión logística es un modelo estadístico para estudiar las relaciones entre un conjunto de variables cualitativas Xi y una variable cualitativa Y. Se trata de un modelo lineal generalizado que utiliza una función logística como función de enlace.
#
# > **i) SVM**
# El objetivo del algoritmo SVM es crear la mejor línea o límite de decisión que pueda segregar el espacio n-dimensional en clases para que podamos colocar fácilmente el nuevo punto de datos en la categoría correcta en el futuro. Este límite de mejor decisión se llama hiperplano. SVM elige los puntos/vectores extremos que ayudan a crear el hiperplano.
#
# > **j) K-neighbors**
# Es un algoritmo de Machine Learning que puede usarse para clasificar nuevas muestras (valores discretos) o para predecir (regresión, valores continuos). Sirve esencialmente para clasificar valores buscando los puntos de datos “más similares” (por cercanía) aprendidos en la etapa de entrenamiento y haciendo conjeturas de nuevos puntos basado en esa clasificación.
#
# > **k) Modelo a implementar**
# Se aplicaran 2 modelos uno regresional con 5 algoritmos diferentes y otro modelo de clasificación con 5 algoritmos diferentes, esto de acuerdo a lo solicitado en el planteamiento original del problema, los algortimos y datos a implementar estaran seleccionados de acuerdo al analisis exploratorio de la información y la correlación de la misma contra las variables objetivo.

# %% [markdown]
# # IV. INGENIERIA

# %% [markdown]
# ## IV.1 DESCRIPCION, AMPLIACION Y/O ABSTRACCION DEL PROBLEMA

# %% [markdown]
# El problema consta de escenarios:
#
# 1.- Escenario a resolver mediante un modelo de regresión para la prediccion del precio de venta de un automovil.
#
# 2.- Escenario a resolver mediante un modelo de clasificación para la predicción del año de un vehiculo asociado a un registro de venta.

# %% [markdown]
# ## IV.2 REFERENCIA DE TECNOLOGIAS A UTILIZAR

# %% [markdown]
# Las tecnologias a utilizar para la resolución del problema son:
#
#
# *   Google Colaboratory, como entorno de desarrollo.
# *   Python, como lenguaje de programación.
# *   Librerias Python, para el manejo de algoritmos de Machine Learning.
#
#        sklearn import metrics
#        sklearn.metrics import confusion_matrix
#        sklearn.metrics import r2_score
#        sklearn.metrics import f1_score
#        sklearn.metrics import median_absolute_error
#        sklearn.metrics import explained_variance_score
#        sklearn.metrics import max_error
#        sklearn.metrics import balanced_accuracy_score
#
# *   Librerias Python, para el manejo de data frames.
#
#        numpy
#        pandas
#
#
# *   Librerias Python, para el manejo de graficos.
#
#        matplotlib.pyplot
#        seaborn

# %% [markdown]
# ## IV.3 ACTIVIDADES Y RESULTADOS

# %% [markdown]
# ### a) PRE-PROCESAMIENTO DE LOS DATOS

# %% [markdown]
# #### a.1) IMPORTAMOS LIBRERIAS Y CARGAMOS DATOS DEL ARCHIVO CSV

# %%
# IMPORTACION DE LIBRERIAS
#Importar librerias graficas
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
#Importar librerias data frames 
import numpy as np
import pandas as pd
#Importar de sklearn Metricas
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import f1_score
from sklearn.metrics import median_absolute_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import balanced_accuracy_score

# %%
# CARGAMOS EL DATASET DE VENTA DE CARROS "car_sales.csv", el archivo se encuentra en un repositorio git compartido publico
url = 'https://raw.githubusercontent.com/Darkour7/MachineLearningII-2022/main/car_sales.csv'
df = pd.read_csv(url)

# %% [markdown]
# #### a.2) EXPLORACION Y ENTENDIMIENTO DE LOS DATOS

# %% [markdown]
# ##### a.2.1) REVISAMOS LOS DATOS DE CABECERA

# %%
df.head()
# Out:
#          AdID                     city  latitude  longitude  mapAddress  \
# 0  1623070279  Burnaby/New Westminster       NaN        NaN         NaN
# 1  1623097429     Delta/Surrey/Langley       NaN        NaN         NaN
# 2  1595531267     Delta/Surrey/Langley       NaN        NaN         NaN
# 3  1623215000     Delta/Surrey/Langley       NaN        NaN         NaN
# 4  1623286366     Delta/Surrey/Langley       NaN        NaN         NaN
#
#                                                title  price saleby  \
# 0                                  Suzuki Jimny 2006  14999  owner
# 1                                  Mustang cobra 99   26000  owner
# 2  2006 Nissan Frontier SE 4X4 - Local BC | No Ac...  13995  owner
# 3                                    1985 Chevy 1500   3300  owner
# 4                          2006 Volkswagen Jetta TDI   2700  owner
#
#          make           model  ...                  Date   visit No of door  \
# ...

# %% [markdown]
# ##### a.2.2) REVISAMOS TIPOS DE DATOS DE LAS COLUMNAS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51343 entries, 0 to 51342
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AdID               51343 non-null  object
#  1   city               51343 non-null  object
#  2   latitude           0 non-null      float64
#  3   longitude          0 non-null      float64
#  4   mapAddress         0 non-null      float64
#  5   title              51342 non-null  object
#  6   price              51343 non-null  int64
#  7   saleby             51343 non-null  object
#  8   make               51343 non-null  object
#  9   model              51343 non-null  object
#  10  Trim               44143 non-null  object
#  11  year               51343 non-null  int64
#  12  condition          51343 non-null  object
#  13  Kilometers         51343 non-null  int64
#  14  body               51343 non-null  object
#  15  Drivetrain         47557 non-null  object
# ...

# %% [markdown]
# ##### a.2.3) VERIFICAR LA CANTIDAD DE DATOS DEL DATASET

# %%
df.shape
# Out:
# (51343, 28)

# %% [markdown]
# RESULTADO: Filas=51343 ; Columnas=28

# %% [markdown]
# ##### a.2.4) VERIFICAR LOS DATOS FALTANTES O NULOS DEL DATASET

# %%
pd.isnull(df).sum()
# Out:
# AdID                     0
# city                     0
# latitude             51343
# longitude            51343
# mapAddress           51343
# title                    1
# price                    0
# saleby                   0
# make                     0
# model                    0
# Trim                  7200
# year                     0
# condition                0
# Kilometers               0
# body                     0
# Drivetrain            3786
# fueltype              3790
# color                 2508
# Date                     0
# visit                  802
# No of door           16678
# No of seats          19514
# Transmission          4004
# push button start    34255
# parking assist       39275
# sunroof              39633
# alloy wheels         32742
# VIN                  51343
# dtype: int64

# %% [markdown]
# Existen columnas completas con valores faltantes o nulos por lo que no seran necesarias para el analisis y podran ser eliminadas en su totalidad

# %%
#Quitamos columnas completamente nulas por no tener datos relavantes y  evitar explosion de dimensiones
df.drop(['latitude','longitude','mapAddress','VIN'], axis=1, inplace = True)  #Columnas enteramente vacias

# %% [markdown]
# Adicionalmente se identifican columnas con datos muy variables como el identificador de venta (AdID) y el (title) con texto descriptivo que no ayudaran al analisis de problema, por lo que dichas columnas seran eliminadas

# %%
#Quitamos columnas con datos no relevantes para el analisis
df.drop(['title','AdID'], axis=1, inplace = True)  #Columnas no tiene relevancia para los calculos

# %% [markdown]
# Volvemos a validar la eliminación de las columnas

# %%
#Verificar eliminacion de columnas nulas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51343 entries, 0 to 51342
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               51343 non-null  object
#  1   price              51343 non-null  int64
#  2   saleby             51343 non-null  object
#  3   make               51343 non-null  object
#  4   model              51343 non-null  object
#  5   Trim               44143 non-null  object
#  6   year               51343 non-null  int64
#  7   condition          51343 non-null  object
#  8   Kilometers         51343 non-null  int64
#  9   body               51343 non-null  object
#  10  Drivetrain         47557 non-null  object
#  11  fueltype           47553 non-null  object
#  12  color              48835 non-null  object
#  13  Date               51343 non-null  object
#  14  visit              50541 non-null  float64
#  15  No of door         34665 non-null  object
# ...

# %% [markdown]
# Se buscan y eliminan filas duplicadas:

# %%
#Se eliminan filas duplicadas
print(f'Tamaño del set antes de eliminar las filas repetidas: {df.shape}')
df.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {df.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (51343, 22)
# Tamaño del set después de eliminar las filas repetidas: (51292, 22)

# %% [markdown]
# De 51343 se redujo a 51292; por lo que existian 51 filas duplicadas

# %% [markdown]
# ##### a.2.5) VERFICAR LAS ESTADISTICAS DEL DATASET

# %% [markdown]
# Validamos las estadisticas completas del dataset tanto para columnas numericas como para columnas categoricas

# %%
df.describe(include = 'all') #incluye valores numericos y categoricos
# Out:
#            city         price  saleby   make  model   Trim          year  \
# count     51292  5.129200e+04   51292  51292  51292  44124  51292.000000
# unique       12           NaN       2     65    741  16416           NaN
# top     Calgary           NaN  dealer   Ford  other     SE           NaN
# freq      17168           NaN   38081   6534   5477    845           NaN
# mean        NaN  3.721878e+04     NaN    NaN    NaN    NaN   2015.554570
# std         NaN  4.424773e+05     NaN    NaN    NaN    NaN      6.877205
# min         NaN  0.000000e+00     NaN    NaN    NaN    NaN   1900.000000
# 25%         NaN  1.378300e+04     NaN    NaN    NaN    NaN   2013.000000
# 50%         NaN  2.938700e+04     NaN    NaN    NaN    NaN   2017.000000
# 75%         NaN  4.999500e+04     NaN    NaN    NaN    NaN   2021.000000
# max         NaN  1.000000e+08     NaN    NaN    NaN    NaN   2023.000000
#
#        condition    Kilometers           body  ...  color  \
# ...

# %% [markdown]
# ##### a.2.6) ANALISIS Y CORRECION COLUMNAS NUMERICAS (VALORES ATIPICOS, NULOS Y OTROS)

# %% [markdown]
# ###### a.2.6.1) ESTADISTICAS Y DISTRIBUCIONES GENERALES PARA LAS COLUMNAS NUMERICAS

# %% [markdown]
# Cuadro de medidas estadisticas de las columnas numericas

# %%
df.describe() # Estadisticas solo valores numericos
# Out:
#               price          year    Kilometers         visit  Transmission  \
# count  5.129200e+04  51292.000000  5.129200e+04  50491.000000  47321.000000
# mean   3.721878e+04   2015.554570  9.782534e+04    294.355331      1.929968
# std    4.424773e+05      6.877205  1.400398e+05    858.755042      0.295783
# min    0.000000e+00   1900.000000  0.000000e+00      0.000000      0.000000
# 25%    1.378300e+04   2013.000000  1.537775e+04     15.000000      2.000000
# 50%    2.938700e+04   2017.000000  7.600000e+04     76.000000      2.000000
# 75%    4.999500e+04   2021.000000  1.500000e+05    261.000000      2.000000
# max    1.000000e+08   2023.000000  9.999999e+06  54064.000000      3.000000
#
#        push button start  parking assist       sunroof  alloy wheels
# count       17085.000000    12067.000000  11710.000000  18600.000000
# mean            0.991981        0.989227      0.991119      0.996237
# std             0.089190        0.103238      0.093825      0.061233
# ...

# %% [markdown]
# Graficas box plot para todas las columnas numericas

# %%
# Generar graficas individuales pues las variables numericas estan en rangos diferentes
cols_num = ['price','year','Kilometers','visit','Transmission','push button start','parking assist','sunroof','alloy wheels']

fig, ax = plt.subplots(nrows=9, ncols=1, figsize=(8,30))
fig.subplots_adjust(hspace=0.5)
for i, col in enumerate(cols_num):
  sns.boxplot(x=col, data=df, ax=ax[i])
  ax[i].set_title(col)

# %% [markdown]
# Se observan anomalias importantes en precio (columna target) muchos valores extremos atipicos, adicionalmente se ven anomalias en kilometros, valores extremos, columnas year y visit tambien con valores extremos

# %% [markdown]
# ###### a.2.6.2) ANALISIS Y CORRECION DE COLUMNA "PRICE"

# %% [markdown]
# Validar valores nulos:

# %%
pd.isnull(df['price']).sum()
# Out:
# 0

# %% [markdown]
# No se tienen valores nulos

# %% [markdown]
# Revisar metricas estadisticas:

# %%
df.price.describe() #Datos estadisticos de la columna precio
# Out:
# count    5.129200e+04
# mean     3.721878e+04
# std      4.424773e+05
# min      0.000000e+00
# 25%      1.378300e+04
# 50%      2.938700e+04
# 75%      4.999500e+04
# max      1.000000e+08
# Name: price, dtype: float64

# %%
df.price.hist() # Histograma de la columna precio

# %%
df.price.plot.box() #GRafico de caja de la columna precio

# %% [markdown]
# Se observan muchos valores extremos o atipicos

# %%
df.price.max()  # Verificar valor maximo
# Out:
# 99999999

# %%
df.loc[df['price'] == 99999999]  #Ver el valor maximo para ver si se trata de un error o una excepcion (valor atipico)
# Out:
#                   city     price saleby        make model Trim  year  \
# 10455  City of Toronto  99999999  owner  volkswagen  golf  NaN  2007
#
#       condition  Kilometers       body  ... color                  Date  \
# 10455   damaged      300000  hatchback  ...   NaN  08/20/2022, 19:25:32
#
#        visit No of door  No of seats Transmission push button start  \
# 10455  166.0        NaN          NaN          NaN               NaN
#
#        parking assist  sunroof  alloy wheels
# 10455             NaN      NaN           NaN
#
# [1 rows x 22 columns]

# %%
df.loc[df['price'] > 500000]  # Ver los carros con precios mayores a 500000 USD
# Out:
#                   city     price  saleby           make      model  \
# 10433  City of Toronto    699800  dealer           Ford      other
# 10455  City of Toronto  99999999   owner     volkswagen       golf
# 10802  City of Toronto    799800  dealer  Mercedes Benz   sl-class
# 16947  City of Toronto    578800  dealer    lamborghini  aventador
# 22743  City of Toronto    619958  dealer       Cadillac        xt5
# 23144  City of Toronto    649899  dealer    Rolls Royce   cullinan
# 43403          Calgary    599995  dealer          Dodge      viper
#
#                                                     Trim  year condition  \
# 10433   550HP, SUPERCHARGED V8, COLLECTORS CAR, 54 MILES  2006      used
# 10455                                                NaN  2007   damaged
# 10802  SL65 AMG Black Series, 1/350 WORLDWIDE, 670HP,...  2009      used
# 16947    S LP 740-4, 740HP, V12, NAV, CLEAR ENGINE COVER  2017      used
# ...

# %% [markdown]
# Borramos todos los valores superiores a 100.000 USD por estar considerados atipicos y constituir menos del 10% del total

# %%
df.drop(df.index[df.price > 100000], axis=0, inplace=True) # Borramos filas con precios mayores a 100,000 USD

# %%
df.price.describe() # Validamos distribucion estadistica sin valores arriba de 100,000 USD
# Out:
# count     50131.000000
# mean      32680.432686
# std       23704.458360
# min           0.000000
# 25%       13000.000000
# 50%       28800.000000
# 75%       48447.000000
# max      100000.000000
# Name: price, dtype: float64

# %%
df.price.hist() # Validamos histograma sin valores arriba de 100,000 USD

# %%
df.price.plot.box() # Validamos nueva distribucion de caja sin valores arriba de 100,000 USD

# %% [markdown]
# Podemos validar que con las acciones realizadas la columna precio se normalizo

# %% [markdown]
# ###### a.2.6.3) ANALISIS Y CORRECION DE COLUMNA "KILOMETERS"

# %% [markdown]
# Validamos existencia valores nulos:

# %%
pd.isnull(df['Kilometers']).sum()
# Out:
# 0

# %% [markdown]
# No existen valores nulos

# %% [markdown]
# Revisamos metricas estadisticas

# %%
df.Kilometers.describe() #Datos estadisticos de la columna precio
# Out:
# count    5.013100e+04
# mean     9.963289e+04
# std      1.410317e+05
# min      0.000000e+00
# 25%      1.802350e+04
# 50%      7.850000e+04
# 75%      1.520000e+05
# max      9.999999e+06
# Name: Kilometers, dtype: float64

# %%
df.Kilometers.hist()

# %%
df.Kilometers.plot.box()

# %% [markdown]
# Podemos apreciar valores atipicos con alta concentración

# %% [markdown]
# Revisamos valores maximos

# %%
#Verificamos columna kilometers
df.Kilometers.max()  # Verificar valor maximo
# Out:
# 9999999

# %%
df.loc[df['Kilometers'] >= 350000]  # Ver los carros con kilometros superiores a 400000 USD
# Out:
#                           city  price  saleby       make           model  \
# 15        Delta/Surrey/Langley   3000   owner       Ford         mustang
# 24        Delta/Surrey/Langley   8000   owner      Dodge  power_ram_3500
# 35     Burnaby/New Westminster      0   owner  Chevrolet  silverado_2500
# 40                   Vancouver   6500   owner      Acura         integra
# 81        Tricities/Pitt/Maple  18500   owner  Chevrolet  silverado_2500
# ...                        ...    ...     ...        ...             ...
# 42305                  Calgary  27500  dealer       Ford           f-350
# 42653                  Calgary   8000   owner      Dodge  power_ram_1500
# 43390                  Calgary  39500   owner       Ford           f-350
# 45741                  Calgary   7999  dealer        Ram            1500
# 48400                  Calgary  33806  dealer       Ford        ecosport
#
#           Trim  year condition  Kilometers           body  ...  color  \
# ...

# %% [markdown]
# Eliminaremos valores atipicos por encima de los 350.000 Km, esto debido a que no consitituyen un porcentaje importante y los mismos se encuentran por fuera del analisis de percentiles

# %%
df.drop(df.index[df.Kilometers >= 350000], axis=0, inplace=True) # Borramos filas con kilometros mayores a 400,000 USD (304 filas borradas + 352 filas (>350K) + 40)

# %%
df.Kilometers.hist()

# %%
df.Kilometers.plot.box()

# %% [markdown]
# En conclusión luego de las acciones aplicadas podemos validar que la columna se encuentra normalizada

# %% [markdown]
# ###### a.2.6.4) ANALISIS Y CORRECION DE COLUMNA "VISIT"

# %%
pd.isnull(df.visit).sum()
# Out:
# 770

# %% [markdown]
# Se tienen 770 registros nulos en el campo VISIT

# %%
df.visit.describe()
# Out:
# count    48667.000000
# mean       273.262211
# std        790.352187
# min          0.000000
# 25%         15.000000
# 50%         72.000000
# 75%        248.000000
# max      54064.000000
# Name: visit, dtype: float64

# %%
df.visit.mean()
# Out:
# 273.26221053280454

# %% [markdown]
# Se remplazan los valores nulos con la media, esto debido a la poca cantidad de los mismos

# %%
df['visit'].replace(np.nan,df.visit.mean(),inplace=True)

# %%
df.visit.hist()

# %%
df.visit.plot.box()

# %% [markdown]
# Se observan demasiados valores atipicos o extremos

# %%
df.loc[df['visit'] > 2000]  # Ver los carros con visit superiores a 2000
# Out:
#                        city  price  saleby        make           model  \
# 1      Delta/Surrey/Langley  26000   owner        Ford         mustang
# 17                 Richmond  19500   owner   Chevrolet  ck_pickup_1500
# 69              North Shore   7900   owner  volkswagen             gti
# 89     Delta/Surrey/Langley  12500   owner        Ford         mustang
# 103                Richmond  11290  dealer      Nissan           other
# ...                     ...    ...     ...         ...             ...
# 49822               Calgary  52545  dealer         Kia         sorento
# 49856               Calgary  76445  dealer       Lexus              rx
# 50325               Calgary  69388  dealer      Toyota          tacoma
# 50678               Calgary  59965  dealer       Lexus              rx
# 50999               Calgary  63345  dealer         Ram            3500
#
#                                           Trim  year condition  Kilometers  \
# ...

# %%
df.drop(df.index[df.visit >= 2000], axis=0, inplace=True) # Borramos 969 filas con valores atipos o extremos

# %%
df.visit.hist()

# %%
df.visit.plot.box()

# %% [markdown]
# Despues de la eliminacion de los valores atipicos la distribución mejoro bastante

# %% [markdown]
# ###### a.2.6.5) ANALISIS Y CORRECION DE COLUMNA "YEAR"

# %%
pd.isnull(df.year).sum()
# Out:
# 0

# %% [markdown]
# No se tiene valores nulos en la columna

# %%
df.year.hist()

# %%
df.year.plot.box()

# %% [markdown]
# Se identifican demasiados valores extremos

# %%
df.loc[df['year'] < 1990]  # Ver los carros con año menor a 1990 (323 rows)
# Out:
#                        city  price saleby       make           model Trim  \
# 3      Delta/Surrey/Langley   3300  owner  Chevrolet  ck_pickup_1500  NaN
# 30     Tricities/Pitt/Maple  11500  owner       Ford           f-350  NaN
# 33     Delta/Surrey/Langley  12000  owner        Bmw        3-series  NaN
# 36     Delta/Surrey/Langley  25000  owner    Pontiac        firebird  NaN
# 51     Delta/Surrey/Langley  12000  owner    Pontiac      grand_prix  NaN
# ...                     ...    ...    ...        ...             ...  ...
# 36287               Calgary  19000  owner  Chevrolet  ck_pickup_1500  NaN
# 36313               Calgary  30000  owner  Chevrolet        corvette  NaN
# 36336               Calgary      0  owner     Nissan           300zx  NaN
# 36340               Calgary   6500  owner        Gmc           other  NaN
# 36352               Calgary      0  owner     Toyota    land_cruiser  NaN
#
#        year condition  Kilometers          body  ...   color  \
# ...

# %%
df.drop(df.index[df.year < 1990], axis=0, inplace=True) # Borramos filas con año < 1990 (323 rows)

# %%
df.year.hist()

# %%
df.year.plot.box()

# %% [markdown]
# Despues de eliminados los valores extremos la distribución mejoro bastante

# %% [markdown]
# ###### a.2.6.6) ANALISIS Y CORRECION DE COLUMNA "TRANSMISSION"

# %%
df.Transmission.unique()
# Out:
# array([ 1.,  2.,  3., nan,  0.])

# %%
pd.isnull(df['Transmission']).sum()
# Out:
# 3670

# %% [markdown]
# Se encontraron 3670 registros nulos

# %%
df.Transmission.hist()

# %%
df.Transmission.describe()
# Out:
# count    44475.000000
# mean         1.935694
# std          0.285303
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: Transmission, dtype: float64

# %%
df.Transmission.replace(np.nan,2,inplace=True) #Asumimos que los 3670 nulos tienen el valor mas comun = 2
# Validar si asumiria el valor 0 para los nulos

# %%
df.Transmission.hist()

# %% [markdown]
# Despues de llenar los nulos con el valor mas frecuente no se observa cambios en la distribucion

# %% [markdown]
# ###### a.2.6.7) ANALISIS Y CORRECION DE COLUMNA "PUSH BUTTON START"

# %%
df['push button start'].unique()
# Out:
# array([nan,  1.,  0.])

# %%
pd.isnull(df['push button start']).sum()
# Out:
# 31863

# %% [markdown]
# Se identifican 31863 registros nulos

# %%
df['push button start'].hist()

# %%
df['push button start'].replace(np.nan,0,inplace=True) #Asumimos que los 31863 tienen el valor 0 ya que lo mas comun es que no tengan boton de arrancado

# %% [markdown]
# Asumimos que los 31863 tienen el valor 0 ya que lo mas comun es que no tengan boton de arrancado

# %%
df.loc[ (df['push button start'] == 1)  & (df['year'] < 2000)]  # Ver los carros con visit superiores a 10000
# Out:
#                   city  price saleby   make   model Trim  year condition  \
# 8618   City of Toronto   4500  owner    Gmc   other  NaN  1997      used
# 23637           Ottawa   5000  owner  Acura      el  NaN  1997      used
# 24202         Gatineau   1700  owner  Honda  accord  NaN  1999      used
# 35273          Calgary   3000  owner   Ford   f-350  NaN  1991      used
# 36245          Calgary   4500  owner  Dodge   other  NaN  1998      used
#
#        Kilometers          body  ...  color                  Date   visit  \
# 8618       268837         other  ...  green  07/20/2022, 14:30:53   553.0
# 23637      167987         sedan  ...  black  07/21/2022, 21:55:57  1459.0
# 24202      250000         sedan  ...  black  08/25/2022, 10:35:56   158.0
# 35273      150000  pickup_truck  ...   gray  08/13/2022, 19:58:00   702.0
# 36245      229141         other  ...  brown  08/25/2022, 16:11:29   131.0
#
#       No of door  No of seats Transmission push button start  parking assist  \
# ...

# %%
df['push button start'].hist()

# %% [markdown]
# Se valida que los registros nulos fueron catalogados con el push button start = 0 (no tiene)

# %% [markdown]
# ###### a.2.6.8) ANALISIS Y CORRECION DE COLUMNA "PARKING ASSIST"

# %%
df['parking assist'].unique()
# Out:
# array([nan,  1.,  0.])

# %%
pd.isnull(df['parking assist']).sum()
# Out:
# 36927

# %% [markdown]
# 36927 valores nulos

# %%
df['parking assist'].hist()

# %%
df['parking assist'].replace(np.nan,0,inplace=True) #Asumimos que los 37150 tienen el valor 0 ya que lo mas comun es que no tengan asistencia de parqueo

# %%
df['parking assist'].hist()

# %% [markdown]
# Los valores nulos se asignan a la caracteristica (no tiene asistencia de parqueo) lo cual es lo mas probable

# %% [markdown]
# ###### a.2.6.9) ANALISIS Y CORRECION DE COLUMNA "SUNROOF"

# %%
df.sunroof.unique()
# Out:
# array([nan,  1.,  0.])

# %%
pd.isnull(df['sunroof']).sum()
# Out:
# 37150

# %% [markdown]
# 37150 valores nulos

# %%
df.sunroof.hist()

# %%
df.sunroof.replace(np.nan,0,inplace=True) #Asumimos que los 37150 tienen el valor 0 ya que lo mas comun es que no tengan techo solar

# %%
df.sunroof.hist()

# %% [markdown]
# Los valores nulos fueron asignados al valor mas comun el cual es que no tenga la caracteristica de techo solar

# %% [markdown]
# ###### a.2.6.10) ANALISIS Y CORRECION DE COLUMNA "ALLOY WHEELS"

# %%
df['alloy wheels'].unique()
# Out:
# array([nan,  1.,  0.])

# %%
pd.isnull(df['alloy wheels']).sum()
# Out:
# 30524

# %% [markdown]
# 30524 valores nulos

# %%
df['alloy wheels'].hist()

# %%
df['alloy wheels'].replace(np.nan,0,inplace=True) #Asumimos que los 30524 tienen el valor 0 ya que lo mas comun es que no tengan alloy wheels

# %%
df['alloy wheels'].hist()

# %% [markdown]
# Los valores nulos fueron cambiados por el valor mas probable, el cual es que no tenga los aros de aleación en la mayor parte de los vehiculos

# %% [markdown]
# ##### a.2.7) ANALISIS, CORRECION y CONVERSION DE COLUMNAS CATEGORICAS (VALORES ATIPICOS, NULOS Y OTROS)

# %%
#Conteo de los niveles en las diferentes columnas categoricas
cols_cat = ['city','saleby','make','model','Trim','condition','body','Drivetrain','fueltype','color','Date','No of door','No of seats']

for col in cols_cat:
  print(f'Columna {col}: {df[col].nunique()} subniveles')
# Out:
# Columna city: 12 subniveles
# Columna saleby: 2 subniveles
# Columna make: 62 subniveles
# Columna model: 688 subniveles
# Columna Trim: 15257 subniveles
# Columna condition: 5 subniveles
# Columna body: 9 subniveles
# Columna Drivetrain: 5 subniveles
# Columna fueltype: 5 subniveles
# Columna color: 19 subniveles
# Columna Date: 42027 subniveles
# Columna No of door: 6 subniveles
# Columna No of seats: 13 subniveles

# %% [markdown]
# ###### a.2.7.1) ANALISIS Y CORRECION DE COLUMNA "CITY"

# %%
df.city.value_counts()
# Out:
# Calgary                    16004
# City of Toronto            14171
# Ottawa                      8321
# Delta/Surrey/Langley        2270
# Gatineau                    1818
# Richmond                    1260
# Vancouver                   1204
# Burnaby/New Westminster     1163
# Tricities/Pitt/Maple        1120
# North Shore                  575
# Downtown-West End            231
# UBC                            8
# Name: city, dtype: int64

# %%
df.city.hist()

# %%
pd.isnull(df['city']).sum()
# Out:
# 0

# %% [markdown]
# No tiene valores nulos

# %%
df.city.describe()
# Out:
# count       48145
# unique         12
# top       Calgary
# freq        16004
# Name: city, dtype: object

# %%
maketypes = df['city'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.city.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.city.hist()

# %% [markdown]
# ###### a.2.7.2) ANALISIS Y CORRECION DE COLUMNA "SALEBY"

# %%
df['saleby'].value_counts()
# Out:
# dealer    36261
# owner     11884
# Name: saleby, dtype: int64

# %%
pd.isnull(df['saleby']).sum()
# Out:
# 0

# %% [markdown]
# No tiene valores nulos

# %%
df.saleby.hist()

# %%
maketypes = df['saleby'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.saleby.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.saleby.hist()

# %% [markdown]
# ###### a.2.7.3) ANALISIS Y CORRECION DE COLUMNA "MAKE"

# %%
df.make.value_counts()
# Out:
# Ford           6149
# Ram            3820
# Toyota         3505
# Chevrolet      3206
# Jeep           2903
#                ...
# Rolls Royce       1
# Alfa Romeo        1
# Lotus             1
# Geo               1
# Mg                1
# Name: make, Length: 62, dtype: int64

# %%
pd.isnull(df['make']).sum()
# Out:
# 0

# %% [markdown]
# No se tienen valores nulos

# %%
maketypes = df['make'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.make.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.make.hist()

# %% [markdown]
# ###### a.2.7.4) ANALISIS Y CORRECION DE COLUMNA "MODEL"

# %%
pd.isnull(df.model).sum()
# Out:
# 0

# %% [markdown]
# No se tienen nulos

# %%
maketypes = df['model'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.model.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.model.hist()

# %% [markdown]
# ###### a.2.7.5) ANALISIS Y CORRECION DE COLUMNA "TRIM"

# %%
df.Trim.describe()
# Out:
# count     41788
# unique    15257
# top          SE
# freq        830
# Name: Trim, dtype: object

# %%
pd.isnull(df.Trim).sum()
# Out:
# 6357

# %% [markdown]
# Tiene 6357 valores nulos

# %%
df.drop(['Trim'], axis=1, inplace=True) # La columna trim fue eliminada

# %% [markdown]
# Se toma la decisión de eliminar la columan "Trim" puesto que la misma presenta alta variabilidad y no represanta información relevanta para el analisis del problema

# %% [markdown]
# ###### a.2.7.6) ANALISIS Y CORRECION DE COLUMNA "CONDITION"

# %%
pd.isnull(df.condition).sum()
# Out:
# 0

# %% [markdown]
# No tiene nulos

# %%
df.condition.hist()

# %%
maketypes = df['condition'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.condition.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.condition.hist()

# %% [markdown]
# ###### a.2.7.7) ANALISIS Y CORRECION DE COLUMNA "BODY"

# %%
pd.isnull(df.body).sum()
# Out:
# 0

# %% [markdown]
# No tiene valores nulos

# %%
maketypes = df['body'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.body.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.body.hist()

# %% [markdown]
# ###### a.2.7.8) ANALISIS Y CORRECION DE COLUMNA "DRIVETRAIN"

# %%
df.Drivetrain.describe()
# Out:
# count     44727
# unique        5
# top         awd
# freq      14444
# Name: Drivetrain, dtype: object

# %%
pd.isnull(df.Drivetrain).sum()
# Out:
# 3418

# %% [markdown]
# Existen 3418 nulos

# %%
df.Drivetrain.replace(np.nan, 'awd',inplace=True)

# %% [markdown]
# Se remplazaron los 3418 nulos con el valor 'awd' que representa al valor de mayor frecuente

# %%
df.Drivetrain.hist()

# %%
maketypes = df['Drivetrain'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.Drivetrain.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos a numericos en una secuencia del 0 hacia adelante

# %%
df.Drivetrain.hist()

# %% [markdown]
# ###### a.2.7.9) ANALISIS Y CORRECION DE COLUMNA "FUELTYPE"

# %%
pd.isnull(df.fueltype).sum()
# Out:
# 3352

# %% [markdown]
# 3352 nulos

# %%
df.fueltype.hist()

# %%
df.fueltype.describe()
# Out:
# count     44793
# unique        5
# top         gas
# freq      28337
# Name: fueltype, dtype: object

# %%
df.fillna({'fueltype': 'gas' }, inplace = True )

# %% [markdown]
# Se remplazan los nulos con el valor mas frecuente (gas)

# %%
maketypes = df['fueltype'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.fueltype.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se cambian los valores categoricos por numeros

# %%
df.fueltype.hist()

# %% [markdown]
# ###### a.2.7.10) ANALISIS Y CORRECION DE COLUMNA "COLOR"

# %%
pd.isnull(df.color).sum()
# Out:
# 2171

# %% [markdown]
# 2171 nulos

# %%
df.color.hist()

# %%
df.fillna({'color': 'white' }, inplace = True )  #ASumimos cambiar los nulos al valor negro el cual es elcolor mas frecuente

# %% [markdown]
# Remplazamos los nulos con el valor mas frecuente (blanco)

# %%
maketypes = df['color'].unique().tolist()
makechanges = [*range(len(maketypes))]
df.color.replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Cambiamos variables categoricas a numericas

# %%
df.color.hist()

# %% [markdown]
# ###### a.2.7.11) ANALISIS Y CORRECION DE COLUMNA "DATE"

# %%
#Obteniendo año de venta y creando calumna year sale
df['year_sale'] = pd.DatetimeIndex(df['Date']).year
df['year_sale'].unique()
# Out:
# array([2022, 2021, 2020, 2019])

# %%
df['year_sale'].hist()

# %% [markdown]
# Se debe evaluar el manejar año y mes para tener mayor variabilidad en los datos

# %% [markdown]
# ###### a.2.7.12) ANALISIS Y CORRECION DE COLUMNA "NO OF DOOR"

# %%
df['No of door'].describe()
# Out:
# count     32502
# unique        6
# top           4
# freq      27535
# Name: No of door, dtype: object

# %%
pd.isnull(df['No of door']).sum()
# Out:
# 15643

# %% [markdown]
# 15643 nulos

# %%
df['No of door'].hist()

# %%
df.fillna({'No of door': '4' }, inplace = True )

# %% [markdown]
# Rellenamos nulos con valor mas frecuente (4 puertas)

# %%
maketypes = df['No of door'].unique().tolist()
makechanges = [*range(len(maketypes))]
df['No of door'].replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Cambiamos variables categoricas a numericas

# %%
df['No of door'].hist()

# %% [markdown]
# ###### a.2.7.13) ANALISIS Y CORRECION DE COLUMNA "NO OF SEATS"

# %%
df['No of seats'].describe()
# Out:
# count     29868
# unique       13
# top           5
# freq      21179
# Name: No of seats, dtype: object

# %%
pd.isnull(df['No of seats']).sum()
# Out:
# 18277

# %% [markdown]
# 18277 nulos

# %%
df['No of seats'].hist()

# %%
df.fillna({'No of seats': '4' }, inplace = True )

# %% [markdown]
# Se remplazan los nulos con el valor mas frecuente (4)

# %%
maketypes = df['No of seats'].unique().tolist()
makechanges = [*range(len(maketypes))]
df['No of seats'].replace(maketypes, makechanges,inplace=True)

# %% [markdown]
# Se convierten las variables categoricas a numericas

# %%
df['No of seats'].hist()

# %% [markdown]
# #### a.3) VISUALIZACION Y CORRELACION DE LOS DATOS

# %% [markdown]
# ##### a.3.1) VISUALIZACION DISTRIBUCION DE TODAS LAS COLUMNAS NUMERICAS Y CATEGORICAS CONVERTIDAS PREVIAMENTE A NUMERICAS

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fef4fd10250>,
# ...
#       dtype=object)

# %% [markdown]
# ##### a.3.2) DIAGRAMAS DE CORRELACION TOMANDO COMO PIVOTE EL PRECIO PARA ANALISIS REGRESIONAL

# %%
#Diagramas de correlacion
#Definir una lista de atributos relevantes para el analisis
from pandas.plotting import scatter_matrix
#atributos = ['city','saleby','make','model','condition','body','Drivetrain','fueltype','color','year_sale','No of door','No of seats','price','year','Kilometers','visit','Transmission','push button start','parking assist','sunroof','alloy wheels'] 
atributos = ['city','saleby','make','model','price'] 
scatter_matrix(df[atributos],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd57ce46d0>,
# ...
#       dtype=object)

# %%
#Diagramas de correlacion
#Definir una lista de atributos relevantes para el analisis
from pandas.plotting import scatter_matrix
#atributos = ['city','saleby','make','model','condition','body','Drivetrain','fueltype','color','year_sale','No of door','No of seats','price','year','Kilometers','visit','Transmission','push button start','parking assist','sunroof','alloy wheels'] 
atributos = ['condition','body','Drivetrain','fueltype','price'] 
scatter_matrix(df[atributos],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd554e0cd0>,
# ...
#       dtype=object)

# %%
#Diagramas de correlacion
#Definir una lista de atributos relevantes para el analisis
from pandas.plotting import scatter_matrix
#atributos = ['city','saleby','make','model','condition','body','Drivetrain','fueltype','color','year_sale','No of door','No of seats','price','year','Kilometers','visit','Transmission','push button start','parking assist','sunroof','alloy wheels'] 
atributos = ['color','year_sale','No of door','No of seats','price'] 
scatter_matrix(df[atributos],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd54cad4d0>,
# ...
#       dtype=object)

# %%
#Diagramas de correlacion
#Definir una lista de atributos relevantes para el analisis
from pandas.plotting import scatter_matrix
#atributos = ['city','saleby','make','model','condition','body','Drivetrain','fueltype','color','year_sale','No of door','No of seats','price','year','Kilometers','visit','Transmission','push button start','parking assist','sunroof','alloy wheels'] 
atributos = ['push button start','parking assist','sunroof','alloy wheels','price'] 
scatter_matrix(df[atributos],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd554e0b90>,
# ...
#       dtype=object)

# %%
#Diagramas de correlacion
#Definir una lista de atributos relevantes para el analisis
from pandas.plotting import scatter_matrix
#atributos = ['city','saleby','make','model','condition','body','Drivetrain','fueltype','color','year_sale','No of door','No of seats','price','year','Kilometers','visit','Transmission','push button start','parking assist','sunroof','alloy wheels'] 
atributos = ['year','Kilometers','visit','Transmission','price'] 
scatter_matrix(df[atributos],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd53c2d050>,
# ...
#       dtype=object)

# %% [markdown]
# ##### a.3.3) MATRIZ DE CORRELACION

# %% [markdown]
# ###### a.3.3.1) MATRIZ DE CORRELACION PARA EL MODELO DE REGRESION (TARGET=PRICE)

# %%
corr_matrix = df.corr().round(3)
corr_target = corr_matrix['price'].sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(x=corr_target.index, y=corr_target.values, ax=ax)

ax.grid(False)
ax.set_title('Attribute Correlation')

plt.setp(ax.get_xticklabels(), rotation=90)

for n, x in enumerate(corr_target.index):
  if corr_target[n] >= 0:
    ax.text(x=n, y=corr_target[n], s=corr_target[n].round(2),
            horizontalalignment='center', verticalalignment='bottom',
            fontsize=14, fontweight='bold')
  else:
    ax.text(x=n, y=corr_target[n], s=corr_target[n].round(2),
            horizontalalignment='center', verticalalignment='top',
            fontsize=14, fontweight='semibold')

ax.axis('tight')    

plt.show()

# %% [markdown]
# ###### a.3.3.2) MATRIZ DE CORRELACION PARA EL MODELO DE CLASIFICACION (TARGET=YEAR)

# %%
corr_matrix = df.corr().round(3)
corr_target = corr_matrix['year'].sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(x=corr_target.index, y=corr_target.values, ax=ax)

ax.grid(False)
ax.set_title('Attribute Correlation')

plt.setp(ax.get_xticklabels(), rotation=90)

for n, x in enumerate(corr_target.index):
  if corr_target[n] >= 0:
    ax.text(x=n, y=corr_target[n], s=corr_target[n].round(2),
            horizontalalignment='center', verticalalignment='bottom',
            fontsize=14, fontweight='bold')
  else:
    ax.text(x=n, y=corr_target[n], s=corr_target[n].round(2),
            horizontalalignment='center', verticalalignment='top',
            fontsize=14, fontweight='semibold')

ax.axis('tight')    

plt.show()

# %% [markdown]
# ### b) DETERMINACION DATOS DE ENTRENAMIENTO, MODELO (JUSTIFICAR LA ELECCION DE FEATURES Y TARGET, COMO LA DIVISION DE TRAIN SET Y TEST SET)

# %% [markdown]
# **MODELO REGRESION:**
#
# **TARGET:** Se utilizara la columna 'price' debido a la importancia y necesidad de calcular la prediccion de este valor.
#
# **ATRIBUTOS DEPENDIENTES:** De acuerdo con la matriz de correlacion se utilizaran las siguientes atributos, que presentan una mayor dependencia con el target (mayor indice de correlación con el target de precio).
#
# ['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels']

# %% [markdown]
# **MODELO CLASIFICACION:**
#
# **TARGET:** Se utilizara la columna 'year' debido a que se vio la necesidad de inferir el modelo y antiguedad de un carro en funcion a una venta realizada.
#
# **ATRIBUTOS DEPENDIENTES:** De acuerdo con la matriz de correlacion se utilizaran las siguientes atributos, que presentan una mayor dependencia con el target (mayor indice de correlación con el target de year).
#
# ['price','Kilometers','condition','saleby']

# %% [markdown]
# **DIVISION DATOS ENTRENAMIENTO / PRUEBA:** Para la separación de los grupos de datos se tomo la decisión de utilizar un 80% de los mismos para el entrenamiento y un 20% para el testeo, basados en practicas de ejemplos utilizados para el estudio y resolución del problema.

# %% [markdown]
# ### c) EJECUCION Y VALIDACION DE MODELOS

# %% [markdown]
# ####c.1) MODELO DE REGRESION

# %% [markdown]
# ##### c.1.1) APLICAR REGRESION LINEAL

# %%
#Librerias necesarias para el la division de datos (train/test) y los algoritmos de regrision lineal
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Se asigna el target "price"
y = np.array(df['price'])

# %%
# Se asignan las variables dependientes
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])

# %%
# Separacion grupos de datos, se instancia el regresor lineal, se entrena y se predice
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test)

# %%
print('Precisión Regresión Lineal:')
print(regressor.score(X_train, y_train))
# Out:
# Precisión Regresión Lineal:
# 0.4796795499579203

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 47,96%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
#METRICAS ADICIONALES PARA LA REGRESION LINEAL
print('1. Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('2. Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('3. R2 Score:', (metrics.r2_score(y_test,y_pred)))
print('4. Max Error:', ( max_error(y_test, y_pred)))
print('5. Explained variance score: ',(explained_variance_score(y_test,y_pred)))
# Out:
# 1. Mean Absolute Error: 12178.26359822009
# 2. Mean Squared Error: 293426106.5227198
# 3. R2 Score: 0.471854976446184
# 4. Max Error: 76337.02050374704
# 5. Explained variance score:  0.4718614088946058

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# ##### c.1.2) APLICAR REGRESION POLINOMIAL

# %%
# Librerias necesarias para la regresion polinomial
from sklearn.preprocessing import PolynomialFeatures
from sklearn import datasets, linear_model


# Se define el target y los atributos dependientes
y = np.array(df['price'])
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])


#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(x, y, test_size=0.2)


#Se define el grado del polinomio a 3 ya que es el que mejor nivel de precision alcanza, se probo con grados 2,4 y 5
poli_reg = PolynomialFeatures(degree = 3)

#Se transforma las características existentes en características de mayor grado
X_train_poli = poli_reg.fit_transform(X_train_p)
X_test_poli = poli_reg.fit_transform(X_test_p)


#Definimos el algoritmo a utilizar
pr = linear_model.LinearRegression()
#Entrenamos el modelo
pr.fit(X_train_poli, y_train_p)

Y_pred_pr = pr.predict(X_test_poli)

# %%
print('Precisión del modelo:')
print(pr.score(X_train_poli, y_train_p))
# Out:
# Precisión del modelo:
# 0.6218311417429967

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 62,18%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
#Metricas adicionales para regresion polinomial
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test_p,Y_pred_pr))
print('Mean Squared Error:', metrics.mean_squared_error(y_test_p,Y_pred_pr))
print('R2 Score:', (metrics.r2_score(y_test_p,Y_pred_pr)))
print('Max Error:', ( max_error(y_test_p,Y_pred_pr)))
print('Explained variance score: ',(explained_variance_score(y_test_p,Y_pred_pr)))
# Out:
# Mean Absolute Error: 10169.800423000255
# Mean Squared Error: 219950151.115213
# R2 Score: 0.6107749275695005
# Max Error: 90954.05426370539
# Explained variance score:  0.610790538349135

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# ##### c.1.3) APLICAR RANDOM FOREST

# %%
# Librerias necesarias para el algortimos Random forest Regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error


def score_dataset(x_train, x_test, y_train, y_test):
    model = RandomForestRegressor(n_estimators=10)
    model.fit(x_train,y_train)
    preds_val = model.predict(x_test)
    mae = mean_absolute_error(y_test,preds_val)
    print("Precisión del modelo")
    print(model.score(x_train, y_train))
    print('METRICAS PARA RANDOM FOREST')
    print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test, preds_val))) 
    print('2. Mean Squared Error:', metrics.mean_squared_error(y_test, preds_val))
    print('3. R2 Score:', (metrics.r2_score(y_test, preds_val)))
    print('4. Max Error:', ( max_error(y_test,preds_val)))
    print('5. Explained variance score: ',(explained_variance_score(y_test, preds_val)))        
    return mae

y = np.array(df['price'])
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])


#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(x, y, test_size=0.2)

print("MAE- Dropeo:")
print(score_dataset(X_train_p,X_test_p, y_train_p, y_test_p))
# Out:
# MAE- Dropeo:
# Precisión del modelo
# 0.95498045463774
# METRICAS PARA RANDOM FOREST
# 1. Mean Absolute Error: 7227.403286576015
# 2. Mean Squared Error: 137501842.51047745
# 3. R2 Score: 0.7518054759059772
# 4. Max Error: 81285.3
# 5. Explained variance score:  0.7519085745136833
# 7227.403286576015

# %% [markdown]
# La precisión del algoritmo es satisfactoria puesto que alcanza al 95,34% de precisión, por lo cual podemos indicar que el algoritmo resuelve el problema de predicción
#
# Las metricas adicionales presentan valores mas adecuados en relación al nivel de precisión del algoritmo

# %% [markdown]
# ##### c.1.4) APLICAR DECISION TREE REGRESION

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
y = np.array(df['price'])
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=41)
treereg = DecisionTreeRegressor(random_state=1,criterion='squared_error')
treereg.fit(X_train, y_train)
# Predecir los precios del set de prueba
preds = treereg.predict(X_test)

print('Precisión del modelo:')
print(treereg.score(X_train, y_train))
# Out:
# Precisión del modelo:
# 0.9979008374067228

# %% [markdown]
# La precisión del algoritmo es satisfactoria puesto que alcanza al 99,79% de precisión, por lo cual podemos indicar que el algoritmo resuelve el problema de predicción

# %%
print('METRICAS ADICIONALES PARA TREE REGRESSION')
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test, preds))) 
print('2. Mean Squared Error:', metrics.mean_squared_error(y_test, preds))
print('3. R2 Score:', (metrics.r2_score(y_test, preds)))
print('4. Max Error:', ( max_error(y_test,preds)))
print('5. Explained variance score: ',(explained_variance_score(y_test, preds)))
# Out:
# METRICAS ADICIONALES PARA TREE REGRESSION
# 1. Mean Absolute Error: 8937.182046858012
# 2. Mean Squared Error: 224112148.822005
# 3. R2 Score: 0.5947099539979483
# 4. Max Error: 99488.0
# 5. Explained variance score:  0.5947565969301234

# %% [markdown]
# Las metricas adicionales presentan valores mas adecuados en relación al nivel de precisión del algoritmo

# %% [markdown]
# ##### c.1.5) APLICAR GRADIENT BOOSTING REGRESSOR

# %%
from sklearn.ensemble import GradientBoostingRegressor

y = np.array(df['price'])
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])

xtrain, xtest, ytrain, ytest=train_test_split(x, y, random_state=12, test_size=0.2)

gbr = GradientBoostingRegressor(n_estimators=600, max_depth=5, learning_rate=0.01, min_samples_split=3)

gbr.fit(xtrain, ytrain)
ypred = gbr.predict(xtest)

print('Precisión del modelo:')
print(gbr.score(xtrain, ytrain))
# Out:
# Precisión del modelo:
# 0.7114246362973538

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 71,14%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
print('METRICAS ADICIONALES PARA TREE REGRESSION')
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(ytest, ypred))) 
print('2. Mean Squared Error:', metrics.mean_squared_error(ytest, ypred))
print('3. R2 Score:', (metrics.r2_score(ytest, ypred)))
print('4. Max Error:', ( max_error(ytest,ypred)))
print('5. Explained variance score: ',(explained_variance_score(ytest, ypred)))
# Out:
# METRICAS ADICIONALES PARA TREE REGRESSION
# 1. Mean Absolute Error: 8198.462977290408
# 2. Mean Squared Error: 166597918.7751105
# 3. R2 Score: 0.6974904241065145
# 4. Max Error: 75323.70418892473
# 5. Explained variance score:  0.697497692665463

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# #### c.2) MODELO DE CLASIFICACION

# %%
# Librerias necesarias para los modelos de clasificacion
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ##### c.2.1) APLICAR Clasificacion Regresion Logistica

# %%
# Se asigna el target y los atributos dependientes

y = np.array(df['year'])
x = np.array(df[['price','Kilometers','condition','saleby'] ])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

##Regresión logística
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)
print('Precisión Regresión Logística:')
print(logreg.score(X_train, y_train))
# Out:
# Precisión Regresión Logística:
# 0.3307716273756361
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 33,07%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
#METRICAS ADICIONALES PARA REGRESION LOGISTICA
print('METRICAS PARA REGRESION LOGISTICA')
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test,Y_pred))) 
print('2. Mean Squared Error:', metrics.mean_squared_error(y_test,Y_pred))
print('3. R2 Score:', (metrics.r2_score(y_test,Y_pred)))
print('4. Max Error:', ( max_error(y_test,Y_pred)))
print('5. Explained variance score: ',(explained_variance_score(y_test,Y_pred)))
# Out:
# METRICAS PARA REGRESION LOGISTICA
# 1. Mean Absolute Error: 2.354346245716066
# 2. Mean Squared Error: 18.341468480631427
# 3. R2 Score: 0.4533059250088529
# 4. Max Error: 31
# 5. Explained variance score:  0.49826564928429995

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# ##### c.2.2) APLICAR Clasificacion SVM

# %%
# Se asigna target y atributos dependientes
y = np.array(df['year'])
x = np.array(df[['price','Kilometers','condition','saleby'] ])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

##Support Vector Machines
svc = SVC()
svc.fit(X_train, y_train)
Y_pred = svc.predict(X_test)
print('Precisión Soporte de Vectores:')
print(svc.score(X_train, y_train))
# Out:
# Precisión Soporte de Vectores:
# 0.34188389240834977

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 34,18%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
#METRICAS ADICIONALES PARA CLASIFICACIÓN SVM
print('METRICAS PARA REGRESION LOGISTICA')
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test,Y_pred))) 
print('2. Mean Squared Error:', metrics.mean_squared_error(y_test,Y_pred))
print('3. R2 Score:', (metrics.r2_score(y_test,Y_pred)))
print('4. Max Error:', ( max_error(y_test,Y_pred)))
print('5. Explained variance score: ',(explained_variance_score(y_test,Y_pred)))
# Out:
# METRICAS PARA REGRESION LOGISTICA
# 1. Mean Absolute Error: 2.2788451552601514
# 2. Mean Squared Error: 17.868210613770902
# 3. R2 Score: 0.47107135077000495
# 4. Max Error: 31
# 5. Explained variance score:  0.5437228003149658

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# ##### c.2.3) APLICAR Clasificacion K-neighbors

# %%
# Se asigna el target y los atributos dependientes
y = np.array(df['year'])
x = np.array(df[['price','Kilometers','condition','saleby','push button start','visit'] ])


X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)


##K neighbors
knn = KNeighborsClassifier(n_neighbors = 3)  # Se elige 3 debido a la recomendacion por defecto de los ejemplos utilizados
knn.fit(X_train, y_train)
Y_pred = knn.predict(X_test)
print('Precisión Vecinos más Cercanos:')
print(knn.score(X_train, y_train))
# Out:
# Precisión Vecinos más Cercanos:
# 0.5749039360265864

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 57,49%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
#METRICAS ADICIONALES PARA K-NEIGHBORS
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test,Y_pred))) 
print('2. Mean Squared Error:', (metrics.mean_squared_error(y_test,Y_pred)))
print('3. R2 Score:', (metrics.r2_score(y_test,Y_pred)))
print('4. Max Error:', ( max_error(y_test,Y_pred)))
print('5. Explained variance score: ',(explained_variance_score(y_test,Y_pred)))
# Out:
# 1. Mean Absolute Error: 3.0391525599750753
# 2. Mean Squared Error: 25.465988160764358
# 3. R2 Score: 0.2349087962565628
# 4. Max Error: 32
# 5. Explained variance score:  0.2940865030655828

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# ##### c.2.4) APLICAR Clasificacion Decision Tree

# %%
# Asignamos target y atributos dependientes
y = np.array(df['year'])
x = np.array(df[['price','Kilometers','condition','saleby','push button start','visit'] ])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

#Modelo de Árboles de Decisión Clasificación
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Árboles de Decisión Clasificación: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión Árboles de Decisión Clasificación: 0.9959497351749922

# %% [markdown]
# La precisión del algoritmo es satisfactoria puesto que alcanza al 99,59%, por lo cual deducimos que es el mejor algoritmo para resolver el modelo planteado

# %%
#METRICAS ADICIONALES PARA DECISION TREE
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test,Y_pred))) 
print('2. Mean Squared Error:', (metrics.mean_squared_error(y_test,Y_pred)))
print('3. R2 Score:', (metrics.r2_score(y_test,Y_pred)))
print('4. Max Error:', ( max_error(y_test,Y_pred)))
print('5. Explained variance score: ',(explained_variance_score(y_test,Y_pred)))
# Out:
# 1. Mean Absolute Error: 2.3263059507737043
# 2. Mean Squared Error: 16.21102918267733
# 3. R2 Score: 0.510352409221718
# 4. Max Error: 28
# 5. Explained variance score:  0.5103829129914559

# %% [markdown]
# Las metricas adicionales presentan valores de acuerdo a la precisión del algoritmo.

# %% [markdown]
# ##### c.2.5) APLICAR Clasificacion Random Forest

# %%
# Asignamos target y atributos dependientes
y = np.array(df['year'])
x = np.array(df[['price','Kilometers','condition','saleby','push button start','visit'] ])


#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(x, y, test_size=0.2)

# Create an instance of Random Forest Classifier
#
forest = RandomForestClassifier(criterion='gini',
                                 n_estimators=5,
                                 random_state=1,
                                 n_jobs=2)
#
# Fit the model
#
forest.fit(X_train, y_train)
 
#
# Measure model performance
#
y_pred = forest.predict(X_test)

print('Accuracy: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.323

# %% [markdown]
# La precisión del algoritmo no es satisfactoria puesto que solo alcanza al 32,3%, por lo cual deducimos que no es el mejor algoritmo para el modelo planteado

# %%
#METRICAS ADICIONALES RANDOM FOREST
print('1. Mean Absolute Error:', (metrics.mean_absolute_error(y_test_p,y_pred))) 
print('2. Mean Squared Error:', (metrics.mean_squared_error(y_test_p,y_pred)))
print('3. R2 Score:', (metrics.r2_score(y_test_p,y_pred)))
print('4. Max Error:', ( max_error(y_test_p,y_pred)))
print('5. Explained variance score: ',(explained_variance_score(y_test_p,y_pred)))
# Out:
# 1. Mean Absolute Error: 6.493924602762489
# 2. Mean Squared Error: 75.282376155364
# 3. R2 Score: -1.198817604018187
# 4. Max Error: 32
# 5. Explained variance score:  -1.191407624786819

# %% [markdown]
# Las metricas adicionales presentan valores no esperados, esto debido a la baja precisión del algoritmo.

# %% [markdown]
# ### d) PREDICCIONES E INTERPRETACION DE RESULTADOS

# %% [markdown]
# #### d.1) PREDICCION MODELO REGRESIONAL

# %%
# Para Random forest necesitamos el siguiente input:
#x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])

print('Ingresar datos para predecir precio:')

city = 13
while city > 12 or city <0:
  entrada = int(input("Introduzca un dato de ciudad entre 0 y 12: "))
  if entrada < 13 and entrada > -1:
    city = entrada
    break

saleby = 3
while saleby > 2 or saleby < 0:
  entrada = int(input("Introduzca un dato de saleby entre 0 y 2: "))
  if entrada < 3 and entrada > -1:
    saleby = entrada
    break

make = 63
while make > 62 or make < 0:
  entrada = int(input("Introduzca un dato de make entre 0 y 62: "))
  if entrada < 63 and entrada > -1:
    make = entrada
    break

model = 689
while model > 688 or model < 0:
  entrada = int(input("Introduzca un dato de model entre 0 y 688: "))
  if entrada < 689 and entrada > -1:
    model = entrada
    break

condition = 6
while condition > 5 or condition <0:
  entrada = int(input("Introduzca un dato de condition entre 0 y 5: "))
  if entrada < 6 and entrada > -1:
    condition = entrada
    break

body = 10
while body > 9 or body< 0:
  entrada = int(input("Introduzca un dato de body entre 0 y 9: "))
  if entrada < 10 and entrada > -1:
    body = entrada
    break

fueltype = 6
while fueltype > 5 or fueltype< 0:
  entrada = int(input("Introduzca un dato de fueltype entre 0 y 5: "))
  if entrada < 6 and entrada > -1:
    fueltype = entrada
    break

color = 20
while color > 19 or color< 0:
  entrada = int(input("Introduzca un dato de color entre 0 y 19: "))
  if entrada < 20 and entrada > -1:
    color = entrada
    break

# year sale array([2022, 2021, 2020, 2019])

year_sale = 2023
while year_sale > 2022 or year_sale< 2019:
  entrada = int(input("Introduzca un dato de year_sale entre 2019 y 2022: "))
  if entrada < 2023 and entrada > 2018:
    year_sale = entrada
    break

door = 7
while door > 6 or door< 0:
  entrada = int(input("Introduzca un dato de door entre 0 y 5: "))
  if entrada < 7 and entrada > -1:
    door = entrada
    break

#####
visit = 2001
while visit > 2000 or visit< 0:
  entrada = int(input("Introduzca un dato de visit entre 0 y 2000: "))
  if entrada < 2001 and entrada > -1:
    visit = entrada
    break  


year= 2024
while year > 2023 or year< 1990:
  entrada = int(input("Introduzca un dato de year entre 1990 y 2023: "))
  if entrada < 2024 and entrada > 1989:
    year = entrada
    break  

kilometers= 350001
while kilometers > 350000 or kilometers< 0:
  entrada = int(input("Introduzca un dato de kilometers entre 0 y 350000: "))
  if entrada < 350001 and entrada > -1:
    kilometers = entrada
    break  

transmission = 4
while transmission > 3 or transmission< 0:
  entrada = int(input("Introduzca un dato de transmission entre 0 y 3: "))
  if entrada < 4 and entrada > -1:
    transmission = entrada
    break  

pushbutton = 2
while pushbutton > 1 or pushbutton< 0:
  entrada = int(input("Introduzca un dato de pushbutton entre 0 y 1: "))
  if entrada < 2 and entrada > -1:
    pushbutton = entrada
    break  


parking = 2
while parking > 1 or parking< 0:
  entrada = int(input("Introduzca un dato de parking entre 0 y 1: "))
  if entrada < 2 and entrada > -1:
    parking = entrada
    break  
sun = 2
while sun > 1 or sun< 0:
  entrada = int(input("Introduzca un dato de sun entre 0 y 1: "))
  if entrada < 2 and entrada > -1:
    sun = entrada
    break  

alloy = 2
while alloy > 1 or alloy< 0:
  entrada = int(input("Introduzca un dato de alloy entre 0 y 1: "))
  if entrada < 2 and entrada > -1:
    alloy = entrada
    break  

testing = [city,saleby,make,model,condition,body,fueltype,color,year_sale,door,visit,year,kilometers,transmission,pushbutton,parking,sun,alloy ]
print (testing)
# Out:
# Ingresar datos para predecir precio:
# Introduzca un dato de ciudad entre 0 y 12: 3
# Introduzca un dato de saleby entre 0 y 2: 2
# Introduzca un dato de make entre 0 y 62: 56
# Introduzca un dato de model entre 0 y 688: 456
# Introduzca un dato de condition entre 0 y 5: 3
# Introduzca un dato de body entre 0 y 9: 6
# Introduzca un dato de fueltype entre 0 y 5: 4
# Introduzca un dato de color entre 0 y 19: 14
# Introduzca un dato de year_sale entre 2019 y 2022: 2021
# Introduzca un dato de door entre 0 y 5: 4
# Introduzca un dato de visit entre 0 y 2000: 1789
# Introduzca un dato de year entre 1990 y 2023: 2022
# Introduzca un dato de kilometers entre 0 y 350000: 250000
# Introduzca un dato de transmission entre 0 y 3: 2
# Introduzca un dato de pushbutton entre 0 y 1: 1
# Introduzca un dato de parking entre 0 y 1: 0
# Introduzca un dato de sun entre 0 y 1: 1
# Introduzca un dato de alloy entre 0 y 1: 0
# [3, 2, 56, 456, 3, 6, 4, 14, 2021, 4, 1789, 2022, 250000, 2, 1, 0, 1, 0]

# %%
# Librerias necesarias para el algortimos Random forest Regressor
from sklearn.ensemble import RandomForestRegressor

y = np.array(df['price'])
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])

X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(x, y, test_size=0.2)

model = RandomForestRegressor(n_estimators=10)
model.fit(X_train_p,y_train_p)
preds_val = model.predict(np.array(testing).reshape(1,-1))
print('Valor predecido con Randon Forest Regressor:')
print(preds_val)
# Out:
# Valor predecido con Randon Forest Regressor:
# [45656.2]

# %%
y = np.array(df['price'])
x = np.array(df[['city','saleby','make','model','condition','body','fueltype','color','year_sale','No of door','visit','year','Kilometers','Transmission','push button start','parking assist','sunroof','alloy wheels'] ])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
treereg = DecisionTreeRegressor(random_state=1,criterion='squared_error')
treereg.fit(X_train, y_train)
# Predecir los precios del set de prueba
preds = treereg.predict(np.array(testing).reshape(1,-1))
print('Valor predecido con Decision Tree Regressor:')
print(preds)
# Out:
# Valor predecido con Decision Tree Regressor:
# [99999.]

# %% [markdown]
# #### d.2) PREDICCION MODELO CLASIFICACION

# %%
print('Ingresar datos para predecir año:')

price = 100001
while price > 100000 or price< 0:
  entrada = int(input("Introduzca un dato de price entre 0 y 100000 :"))
  if entrada < 100001 and entrada > -1:
    price = entrada
    break  


saleby = 3
while saleby > 2 or saleby < 0:
  entrada = int(input("Introduzca un dato de saleby entre 0 y 2: "))
  if entrada < 3 and entrada > -1:
    saleby = entrada
    break


condition = 6
while condition > 5 or condition <0:
  entrada = int(input("Introduzca un dato de condition entre 0 y 5: "))
  if entrada < 6 and entrada > -1:
    condition = entrada
    break


#####
visit = 2001
while visit > 2000 or visit< 0:
  entrada = int(input("Introduzca un dato de visit entre 0 y 2000: "))
  if entrada < 2001 and entrada > -1:
    visit = entrada
    break  


kilometers= 350001
while kilometers > 350000 or kilometers< 0:
  entrada = int(input("Introduzca un dato de kilometers entre 0 y 350000: "))
  if entrada < 350001 and entrada > -1:
    kilometers = entrada
    break  

pushbutton = 2
while pushbutton > 1 or pushbutton< 0:
  entrada = int(input("Introduzca un dato de pushbutton entre 0 y 1: "))
  if entrada < 2 and entrada > -1:
    pushbutton = entrada
    break  



testing = [price,kilometers,condition,saleby, pushbutton, visit]
print (testing)
# Out:
# Ingresar datos para predecir año:
# Introduzca un dato de price entre 0 y 100000 :54000
# Introduzca un dato de saleby entre 0 y 2: 1
# Introduzca un dato de condition entre 0 y 5: 4
# Introduzca un dato de visit entre 0 y 2000: 1567
# Introduzca un dato de kilometers entre 0 y 350000: 250000
# Introduzca un dato de pushbutton entre 0 y 1: 1
# [54000, 250000, 4, 1, 1, 1567]

# %%
# Asignamos target y atributos dependientes
y = np.array(df['year'])
x = np.array(df[['price','Kilometers','condition','saleby','push button start','visit'] ])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

#Modelo de Árboles de Decisión Clasificación
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(np.array(testing).reshape(1,-1))
print('Valor (AÑO) predecido con Decision Tree Classifier:')
print(Y_pred)
# Out:
# Valor (AÑO) predecido con Decision Tree Classifier:
# [2021]

# %% [markdown]
# # V. CONCLUSIONES

# %% [markdown]
# Como resultado del proyecto se obtenieron las siguientes conclusiones:
#
#
# *   Para el modelo de regresión, se encontro que el algoritmo de Arbol de desicion para regresión es el que presenta mayor precision para el tipo de problema de predicción del precio de venta de un vehiculo, tomando en consideración los atributos dependientes y relevantes del dataset provisto.
#
# *   Para el modelo de regresión, otros algoritmos como el de regresión lineal y regresión polinomial, no presentaron una buena precisión debido a la no existencia de un indice de correlación elevado entre los diferentes atributos, ningun caso presentaba una tendencia lineal y si bien en alguna correlación se veia una tendencia polinamial, la misma no se podia ajustar.
#
# *   Para el modelo de regresión, el algoritmo de Random Forest para regresión presenta tambien una buena precision, para el tipo de problema de predicción del precio de venta de un vehiculo, tomando en consideración los atributos dependientes y relevantes del dataset provisto, por lo que se considera con una segunda opcion de solución.
#
# *   Para el modelo de clasificación, se encontro que el algoritmo de Decision Tree para clasificación es el que presenta mayor precision para el tipo de problema de clasificación del año del modelo de un vehiculo, tomando en consideración los atributos dependientes y relevantes del dataset provisto.
#
# *   Para el modelo de clasificación, otros algoritmos como el de regresión logistica,  k-neighbors, SVM o Random Forest no presentaron una buena precisión debido a la no existencia de un indice de correlación elevado entre los diferentes atributos.
#
# *   Durante la elaboracion del proyecto, pudimos constatar que la fase mas compleja fue la de pre-procesamiento de la información, puesto que algun caso existieron muchos datos perdidos los cuales no necesariamente deberian ser eliminados, mas por el contrario se trata de imputar los mismos con los valores de la media, la moda o en algun caso incluso no se llego a utilizar un valor estadistico, sino que se utilizo un valor subjetivo aplicado al contexto del problema de venta de autos de acuerdo a su mayor probabilidad, por ejemplo el item "parqueo asistido" no es valor comun, por lo que los nulos se rellenaron con el valor contrario, es decir que no dispone de esa caracteristica.
#
# *   Para el cambio de valores categoricos a valores numericos por lo general se utilizo una regla de secuencial de asignacion para los valores numericos, puesto que no se identifico que corresponda un peso ordinal a dichos valores.
#
# *   Se encontraron varias columnas completamente irrelevantes para el analisis del problema.
#
# *   No se encontraron indices de correlación bastante fuertes, los mejores indices solo bordeaban el 0.5.
#
# *   Se encontraron muchos valores en distintas columnas que eran outliers (valores atipicos o extremos) correspondientes a errores en la información, como tambien valores extremos reales correspondientes a excepciones, las cuales tuvieron que de igual forma ser eliminadas puesto que afectaban a la distribucion de los datos.
#
# *   No se encontraron indices de correlación bastante fuertes, los mejores indices solo bordeaban el 0.5.
#
# *   Para La division de los datos en entrenamiento y pruebas se utilizo una relacion 80% / 20% esto de acuerdo a las practicas revisadas en ejemplos de estudio.

# %% [markdown]
# # VI. BIBLIOGRAFIA

# %% [markdown]
# *   Aurelian Geron, Hands-on Machine Learning.
# *   Tom Mitchell, Machine Learning.
# *   Documentacion de ayuda libreria "Sklearn"
# *   Documentacion de ayuda libreria "Pandas"
# *   Documentacion de ayuda libreria "Matlib"
# *   https://www.youtube.com/c/AprendeIAconLigdiGonzalez
# *   https://www.youtube.com/c/codificandobits
